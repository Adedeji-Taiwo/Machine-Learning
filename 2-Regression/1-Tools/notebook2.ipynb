# %% [markdown]
# Linear Regression: Diabetes Progression Against Blood Sugar Level

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_diabetes(return_X_y=True) # X is the 10 column features while y is the single column target or label
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X = X[:, 9]
X = X.reshape((-1, 1))
print(X)
# Out:
# [[-0.01764613]
#  [-0.09220405]
#  [-0.02593034]
#  [-0.00936191]
#  [-0.04664087]
#  [-0.09634616]
#  [-0.03835666]
#  [ 0.00306441]
#  [ 0.01134862]
#  [-0.01350402]
#  [-0.03421455]
#  [-0.05906719]
#  [-0.04249877]
#  [-0.01350402]
#  [-0.07563562]
#  [-0.04249877]
#  [ 0.02791705]
#  [-0.0010777 ]
#  [-0.01764613]
#  [-0.05492509]
#  [ 0.01549073]
#  [-0.01764613]
#  [-0.01350402]
#  [ 0.13561183]
#  [-0.05492509]
#  [-0.03421455]
#  [-0.0052198 ]
#  [ 0.04034337]
#  [-0.05492509]
#  [ 0.05276969]
#  [-0.00936191]
#  [-0.04249877]
#  [ 0.02791705]
#  [ 0.00306441]
#  [-0.06735141]
#  [ 0.01963284]
#  [-0.02593034]
#  [-0.0052198 ]
#  [ 0.02377494]
#  [ 0.00306441]
#  [ 0.09419076]
#  [-0.00936191]
#  [-0.03421455]
#  [ 0.07348023]
#  [-0.01764613]
#  [-0.05078298]
#  [-0.08806194]
#  [-0.08391984]
#  [-0.02178823]
#  [-0.01350402]
#  [ 0.00720652]
#  [-0.02178823]
#  [-0.01350402]
#  [ 0.04862759]
#  [ 0.00720652]
#  [ 0.00720652]
#  [-0.01764613]
#  [-0.06735141]
# ...

# %%
#split both the data (X) and the target (y) into test and training sets 70%-30%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
#Train model using linear regrression using model fit
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#create a prediction using test data to draw the line between data groups
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='green', linewidth=3)
plt.xlabel('Scaled Blood Sugar')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against Blood Sugar')
plt.show()
